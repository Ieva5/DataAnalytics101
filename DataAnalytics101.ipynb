# %% [markdown]
# This is the title

# %%
 1+2
# Out:
# 3

# %%
print("this is a string")
# Out:
# this is a string

# %%
4*5
# Out:
# 20

# %%
example = 2+3
example
print(example)

example1 = 6*2
print(example1)
# Out:
# 5
# 12

# %%
import pandas as pd

# %% [markdown]
# #Data Manipulatios

# %%
data = pd.read_csv("customer_shopping_data.csv")
print(data)
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
data
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
#let's explore dataset

# %%
data.head(20)
# Out:
#    invoice_no customer_id  gender  age         category  quantity    price  \
# 0     I138884     C241288  Female   28         Clothing         5  1500.40
# 1     I317333     C111565    Male   21            Shoes         3  1800.51
# 2     I127801     C266599    Male   20         Clothing         1   300.08
# 3     I173702     C988172  Female   66            Shoes         5  3000.85
# 4     I337046     C189076  Female   53            Books         4    60.60
# 5     I227836     C657758  Female   28         Clothing         5  1500.40
# 6     I121056     C151197  Female   49        Cosmetics         1    40.66
# 7     I293112     C176086  Female   32         Clothing         2   600.16
# 8     I293455     C159642    Male   69         Clothing         3   900.24
# 9     I326945     C283361  Female   60         Clothing         2   600.16
# 10    I306368     C240286  Female   36  Food & Beverage         2    10.46
# ...

# %%
data.tail(25)
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 99432    I133264     C289915  Female   41            Books         2    30.30
# 99433    I403904     C142643    Male   28             Toys         1    35.84
# 99434    I186560     C117024  Female   39            Shoes         1   600.17
# 99435    I141871     C298790  Female   62         Clothing         3   900.24
# 99436    I579905     C265057  Female   57         Clothing         5  1500.40
# 99437    I662891     C180055  Female   50        Cosmetics         3   121.98
# 99438    I161104     C363191  Female   47             Toys         5   179.20
# 99439    I522661     C776199  Female   58  Food & Beverage         4    20.92
# 99440    I887161     C137631  Female   58         Clothing         1   300.08
# 99441    I203187     C235554    Male   38  Food & Beverage         4    20.92
# 99442    I105959     C131810  Female   45         Clothing         4  1200.32
# ...

# %%
data.shape
# Out:
# (99457, 10)

# %%
data.columns
# Out:
# Index(['invoice_no', 'customer_id', 'gender', 'age', 'category', 'quantity',
#        'price', 'payment_method', 'invoice_date', 'shopping_mall'],
#       dtype='object')

# %%
data.dtypes
# Out:
# invoice_no         object
# customer_id        object
# gender             object
# age                 int64
# category           object
# quantity            int64
# price             float64
# payment_method     object
# invoice_date       object
# shopping_mall      object
# dtype: object

# %% [markdown]
# # age and price

# %%
data['category']
# Out:
# 0               Clothing
# 1                  Shoes
# 2               Clothing
# 3                  Shoes
# 4                  Books
#               ...
# 99452           Souvenir
# 99453    Food & Beverage
# 99454    Food & Beverage
# 99455         Technology
# 99456           Souvenir
# Name: category, Length: 99457, dtype: object

# %%
data['age']
# Out:
# 0        28
# 1        21
# 2        20
# 3        66
# 4        53
#          ..
# 99452    45
# 99453    27
# 99454    63
# 99455    56
# 99456    36
# Name: age, Length: 99457, dtype: int64

# %%
age = data["age"]
print(age)
# Out:
# 0        28
# 1        21
# 2        20
# 3        66
# 4        53
#          ..
# 99452    45
# 99453    27
# 99454    63
# 99455    56
# 99456    36
# Name: age, Length: 99457, dtype: int64

# %%
age = data["age"]
age
# Out:
# 0        28
# 1        21
# 2        20
# 3        66
# 4        53
#          ..
# 99452    45
# 99453    27
# 99454    63
# 99455    56
# 99456    36
# Name: age, Length: 99457, dtype: int64

# %% [markdown]
# #Different Values

# %%
data['category']
# Out:
# 0               Clothing
# 1                  Shoes
# 2               Clothing
# 3                  Shoes
# 4                  Books
#               ...
# 99452           Souvenir
# 99453    Food & Beverage
# 99454    Food & Beverage
# 99455         Technology
# 99456           Souvenir
# Name: category, Length: 99457, dtype: object

# %%
print("This is the number of differnet values", age.nunique())

print("These are all the possible values", age.unique())

print("These are the counts of each value \n", age.value_counts())
# Out:
# This is the number of differnet values 52
# These are all the possible values [28 21 20 66 53 49 32 69 60 36 29 67 25 24 65 42 46 23 27 52 44 51 50 68
#  43 59 54 48 40 41 19 18 22 61 45 64 33 63 34 47 38 57 30 26 62 39 55 56
#  35 31 37 58]
# These are the counts of each value
#  37    2057
# 22    2051
# 64    2002
# 43    2000
# 51    1993
# 30    1981
# 24    1977
# 40    1960
# 48    1955
# 36    1954
# 38    1954
# 28    1953
# 27    1950
# 39    1947
# 21    1947
# 61    1945
# 52    1945
# 19    1936
# 56    1916
# 33    1913
# 46    1911
# 62    1909
# 44    1904
# 53    1903
# 67    1901
# 69    1901
# 23    1897
# 26    1896
# 68    1893
# 42    1892
# 41    1892
# 32    1891
# 63    1886
# 29    1885
# 49    1883
# 34    1883
# 47    1880
# 57    1879
# 66    1876
# 45    1876
# 58    1875
# 59    1874
# 60    1874
# 50    1873
# 31    1866
# 25    1863
# 65    1856
# 18    1844
# 20    1844
# 55    1843
# 35    1841
# 54    1830
# Name: age, dtype: int64

# %%
age.count()
print(" This is the count command", age.count())
# Out:
#  This is the count command 99457

# %%
age.sum()
print("This is the sum command", age.sum())
# Out:
# This is the sum command 4319128

# %%
print("this is double the age \n", age*2)
# Out:
# this is double the age
#  0         56
# 1         42
# 2         40
# 3        132
# 4        106
#         ...
# 99452     90
# 99453     54
# 99454    126
# 99455    112
# 99456     72
# Name: age, Length: 99457, dtype: int64

# %%
age_double = age*2
age_double
# Out:
# 0         56
# 1         42
# 2         40
# 3        132
# 4        106
#         ...
# 99452     90
# 99453     54
# 99454    126
# 99455    112
# 99456     72
# Name: age, Length: 99457, dtype: int64

# %%
quantity = data['quantity']
print(age - quantity)
# Out:
# 0        23
# 1        18
# 2        19
# 3        61
# 4        49
#          ..
# 99452    40
# 99453    25
# 99454    61
# 99455    52
# 99456    33
# Length: 99457, dtype: int64

# %%
price = data['price']
print("This is what Black Friday discount looks like \n", price*1.25)
# Out:
# This is what Black Friday discount looks like
#  0        1875.5000
# 1        2250.6375
# 2         375.1000
# 3        3751.0625
# 4          75.7500
#            ...
# 99452      73.3125
# 99453      13.0750
# 99454      13.0750
# 99455    5250.0000
# 99456      43.9875
# Name: price, Length: 99457, dtype: float64

# %%
price =  data["price"]
price_discount = price * 0.25
data["discount"] = price_discount
data["aged"] = age + 1

data
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %% [markdown]
# Group by

# %%
data.groupby('category').count()
# Out:
#                  invoice_no  customer_id  gender    age  quantity  price  \
# category
# Books                  4981         4981    4981   4981      4981   4981
# Clothing              34487        34487   34487  34487     34487  34487
# Cosmetics             15097        15097   15097  15097     15097  15097
# Food & Beverage       14776        14776   14776  14776     14776  14776
# Shoes                 10034        10034   10034  10034     10034  10034
# Souvenir               4999         4999    4999   4999      4999   4999
# Technology             4996         4996    4996   4996      4996   4996
# Toys                  10087        10087   10087  10087     10087  10087
#
#                  payment_method  invoice_date  shopping_mall   aged
# category
# Books                      4981          4981           4981   4981
# Clothing                  34487         34487          34487  34487
# Cosmetics                 15097         15097          15097  15097
# ...

# %%
data.groupby('category')[['price']].sum()
# Out:
#                        price
# category
# Books              226977.30
# Clothing         31075684.64
# Cosmetics         1848606.90
# Food & Beverage    231568.71
# Shoes            18135336.89
# Souvenir           174436.83
# Technology       15772050.00
# Toys              1086704.64

# %%
data.groupby(['category', 'payment_method'])[['price']].sum()
# Out:
#                                       price
# category        payment_method
# Books           Cash              103489.65
#                 Credit Card        76689.30
#                 Debit Card         46798.35
# Clothing        Cash            13966323.36
#                 Credit Card     10765970.16
#                 Debit Card       6343391.12
# Cosmetics       Cash              810394.46
#                 Credit Card       662066.78
#                 Debit Card        376145.66
# Food & Beverage Cash              102628.29
#                 Credit Card        82592.16
#                 Debit Card         46348.26
# Shoes           Cash             8097493.64
#                 Credit Card      6433222.23
#                 Debit Card       3604621.02
# Souvenir        Cash               76080.78
#                 Credit Card        62380.14
#                 Debit Card         35975.91
# Technology      Cash             7056000.00
#                 Credit Card      5586000.00
# ...

# %%
data.groupby(['category', 'payment_method'])['price'].sum()
# Out:
# category         payment_method
# Books            Cash                103489.65
#                  Credit Card          76689.30
#                  Debit Card           46798.35
# Clothing         Cash              13966323.36
#                  Credit Card       10765970.16
#                  Debit Card         6343391.12
# Cosmetics        Cash                810394.46
#                  Credit Card         662066.78
#                  Debit Card          376145.66
# Food & Beverage  Cash                102628.29
#                  Credit Card          82592.16
#                  Debit Card           46348.26
# Shoes            Cash               8097493.64
#                  Credit Card        6433222.23
#                  Debit Card         3604621.02
# Souvenir         Cash                 76080.78
#                  Credit Card          62380.14
#                  Debit Card           35975.91
# Technology       Cash               7056000.00
# ...

# %%
data.groupby('category')[['price']].sum()
# Out:
#                        price
# category
# Books              226977.30
# Clothing         31075684.64
# Cosmetics         1848606.90
# Food & Beverage    231568.71
# Shoes            18135336.89
# Souvenir           174436.83
# Technology       15772050.00
# Toys              1086704.64

# %% [markdown]
# Descriptive analytics

# %%
age.max()
print("maximum client age", age.max())
# Out:
# maximum client age 69

# %%
age.min()
print("minimum client age", age.min())
# Out:
# minimum client age 18

# %%
age.mean()
# Out:
# 43.42708909377922

# %%
price = data.price
price.mean()
# Out:
# 689.2563209226097

# %%
price.median()
# Out:
# 203.3

# %%
price.mode()
# Out:
# 0    600.16
# Name: price, dtype: float64

# %%
price.mode()
# Out:
# 0    600.16
# Name: price, dtype: float64

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #Histogram

# %%
plt.hist(age)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Skatter plot

# %%
plt.scatter(data["age"], data['price'])
plt.title('Price vs. Age')
plt.xlabel('Age')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# Boxplot

# %%
plt.boxplot(age)
plt.title('Age distribution')
plt.xlabel('Age')
plt.show()

# %%
plt.boxplot(price)
plt.title('Price distribution')
plt.xlabel('Price')
plt.show()
